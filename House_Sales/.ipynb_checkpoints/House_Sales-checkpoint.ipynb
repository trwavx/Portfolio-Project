# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns
import folium
# %matplotlib inline

from matplotlib import rcParams
rcParams['figure.figsize'] = 15, 15

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df2 = df.drop(columns = ['id', 'date', 'zipcode'])

# %%
df2.head(5)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
df2.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sns.heatmap(df.corr('pearson'), annot=True, data=df)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x='sqft_living', y='price', data=df)

plt.title('sqft_living vs price')
plt.show()

# %%
sns.regplot(x='sqft_above', y='price', data=df)

plt.title('sqft_above vs price')
plt.show()

# %%
sns.regplot(x='sqft_living15', y='price', data=df)

plt.title('sqft_living15 vs price')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = df2.drop(columns = ['price'])

# %%
y = df2.price

# %%
print('x size: ', x.shape)
print('y size: ', y.shape)
# Out:
# x size:  (21613, 17)
# y size:  (21613,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

# %%
print('x train size: ', x_train.shape)
print('y train size: ', y_train.shape)
# Out:
# x train size:  (14408, 17)
# y train size:  (14408,)

# %%
print('x test size: ', x_test.shape)
print('y test size: ', y_test.shape)
# Out:
# x test size:  (7205, 17)
# y test size:  (7205,)

# %% [markdown]
# # Linear Regression

# %%
lr = LinearRegression()

lr.fit(x_train, y_train)
print('Score: ', lr.score(x_test, y_test))
# Out:
# Score:  0.679802876789301

# %%
yhat = lr.predict(x_test)

ax1 = sns.distplot(df['price'], hist = False, color = "r", label = "Actual Value")
sns.distplot(yhat, hist = False, color = "b", label = "Predict Values", ax = ax1)

plt.title('Actual price vs Predict price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Features')
plt.show()
# Out:
# C:\Users\anhvu\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\anhvu\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We can see that the fitted values are reasonably close to the actual values since the two distributions overlap a bit. However, there is definitely some room for improvement.

# %% [markdown]
# # Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

# %%
Input = [('scaler', StandardScaler()), ('poly', PolynomialFeatures(include_bias=False)), ('linear', LinearRegression())]

# %%
pipe = Pipeline(Input)

pipe.fit(x_train, y_train)
print('Score: ', pipe.score(x_test, y_test))
# Out:
# Score:  0.8006348825714957

# %%
yhat2 = pipe.predict(x_test)

ax1 = sns.distplot(df.price, hist=False, color='r', label='Actual Price')
sns.distplot(yhat2, hist=False, color='b', label='Fitted Price', ax=ax1)

plt.title('Polynomial Actual price vs Fitted price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Features')
plt.show()
# Out:
# C:\Users\anhvu\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\anhvu\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We can see that the fitted values way close to the actual value. But we have a little overfitting.
#
# We will now use Ridge Regression to regularize and reduce the standard errors to fix the over-fitting in this model.

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
r = Ridge(alpha=0.1)

r.fit(x_train, y_train)
r.score(x_test, y_test)
# Out:
# 0.6798113981109165

# %%
yhat3 = r.predict(x_test)

ax1 = sns.distplot(df.price, hist=False, color='r', label='Actual Price')
sns.distplot(yhat3, hist=False, color='b', label='Predict Price', ax=ax1)

plt.title('RR Actual price vs Fitted price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Features')
plt.show()
# Out:
# C:\Users\anhvu\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\anhvu\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We can see that the fitted values are reasonably close to the actual values since the two distributions overlap a bit. However, there is definitely some room for improvement.
